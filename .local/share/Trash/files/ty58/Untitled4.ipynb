# %%
import numpy as np
import matplotlib.pyplot as plt

rand_arr=np.random.randint(0,100,50)

print("\n ****** Random numbers ******* \n",rand_arr)

x=rand_arr
y=x
plt.plot(x,color='red')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Line Chart")
plt.show()



plt.scatter(x,y,marker='s',c='blue')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Scatter")
plt.show()


plt.hist(x,color='green')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Histogram")
plt.show()


plt.boxplot(x)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Box Plot")
plt.show()
# Out:
#  ****** Random numbers *******
#  [74 21 29 58 53  3 64  6 65 29 75 19 34 14 87  9 56 74 37 79 22  3 45  3
#  92 61 28 47 94 96 95  0 27 59  0 95 90 57 17 19 66 30 82 63 16 35 29 17
#   2 80]
