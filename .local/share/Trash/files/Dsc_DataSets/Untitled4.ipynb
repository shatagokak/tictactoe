# %%
import pandas as pd
import numpy as np
data = pd.read_csv('HeightWeight.csv')
df=pd.DataFrame(data)
print("\n Number of observations: ",df['Index'].size)
missing = df.isnull()
print("\m Missing Values: \n",missing)
nan_values = np.isnan(df)
print("\n nan values :",nan_values)
# Out:
#  Number of observations:  25000
# \m Missing Values:
#         Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]
#
#  nan values :        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# ...

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('HeightWeight.csv')
df = pd.DataFrame(data)
df['BMI']=(df['Weight(Pounds)']/df['Height(Inches)']**2)
print("***After adding Column dataframe is:***\n",df)
# Out:
# ***After adding Column dataframe is:***
#         Index  Height(Inches)  Weight(Pounds)       BMI
# 0          1        65.78331        112.9925  0.026111
# 1          2        71.51521        136.4873  0.026687
# 2          3        69.39874        153.0269  0.031773
# 3          4        68.21660        142.3354  0.030587
# 4          5        67.78781        144.2971  0.031402
# ...      ...             ...             ...       ...
# 24995  24996        69.50215        118.0312  0.024434
# 24996  24997        64.54826        120.1932  0.028848
# 24997  24998        64.69855        118.2655  0.028253
# 24998  24999        67.52918        132.2682  0.029005
# 24999  25000        68.87761        124.8742  0.026322
#
# [25000 rows x 4 columns]

# %%
import numpy as np
data=pd.read_csv('HeightWeight.csv')
df=pd.DataFrame(data)
df ['BMI']=(df['Weight(Pounds)']/df['Height(Inches)']**2)
print("Maximum BMI:\n", max(df ['BMI']))
print("Minimum BMI:\n", min(df ['BMI']))
# Out:
# Maximum BMI:
#  0.03701443692089851
# Minimum BMI:
#  0.018591137267932455

# %%
import pandas as pd 
import matplotlib.pyplot as plt
data=pd.read_csv('HeightWeight.csv')
df=pd.DataFrame(data)
df['BMI']=((df['Weight(Pounds)']/df['Height(Inches)'])**2)
plt.scatter(x=df['Height(Inches)'],y=df['Weight(Pounds)'],c='lightblue')
plt.title("Scatter PLot")
plt.xlabel("Height(Inches)")
plt.ylabel("Weight(Pounds)")
plt.show()

# %%
import pandas as pd 
import numpy as np
arr=np.array([[30,75,70,], [80,90,20], [50,95,60]])
print (arr)
print ("Mean: ",np.mean(arr))
print ("Median: ",np.median(arr))
# Out:
# [[30 75 70]
#  [80 90 20]
#  [50 95 60]]
# Mean:  63.333333333333336
# Median:  70.0

# %%
import pandas as pd 
import numpy as np
d = {'Name': pd.Series(['Ram','sham', 'Meena', 'Seeta', 'Geeta', 'Rakesh', 'Madhav']), 'Age': pd.Series ([25,26,25,23,30,29,23]), 'Rating': pd.Series ([4.23,3.2,4,3.98,2.56,3.20,4.6,3.8])}
df = pd.DataFrame (d)
print(df.sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       3 d = {'Name': pd.Series(['Ram','sham', 'Meena', 'Seeta', 'Geeta', 'Rakesh', 'Madhav']), 'Age': pd.Series ([25,26,25,23,30,29,23]), 'Rating': pd.Series ([4.23,3.2,4,3.98,2.56,3.20,4.6,3.8])}
#       4 df = pd.DataFrame (d)
# ----> 5 print(df.sum())
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11670, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11661 @doc(make_doc("sum", ndim=2))
#   11662 def sum(
#   11663     self,
#    (...)
#   11668     **kwargs,
#   11669 ):
# > 11670     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671     return result.__finalize__(self, method="sum")
#
# ...

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
print(df)
# Out:
#      Name  Age  Percentage
# 0  Shadab   20          69
# 1    Aman   22          98
# 2    Awez   20          89
# 3    Ghar   20          75
# 4  Abuzar   20          70

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
print(df)
print("The Shape:",df.shape)
print("No.of ROws,Columns:",df.size)
print("Data Types:",df.dtypes)
print("Feature name:",df.columns)
print("Description:",df.describe())
# Out:
#      Name  Age  Percentage
# 0  Shadab   20          69
# 1    Aman   22          98
# 2    Awez   20          89
# 3    Ghar   20          75
# 4  Abuzar   20          70
# The Shape: (5, 3)
# No.of ROws,Columns: 15
# Data Types: Name          object
# Age            int64
# Percentage     int64
# dtype: object
# Feature name: Index(['Name', 'Age', 'Percentage'], dtype='object')
# Description:              Age  Percentage
# count   5.000000    5.000000
# mean   20.400000   80.200000
# std     0.894427   12.755391
# min    20.000000   69.000000
# 25%    20.000000   70.000000
# 50%    20.000000   75.000000
# 75%    20.000000   89.000000
# max    22.000000   98.000000

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
print(df)
print("statical data:",df.describe())
# Out:
#      Name  Age  Percentage
# 0  Shadab   20          69
# 1    Aman   22          98
# 2    Awez   20          89
# 3    Ghar   20          75
# 4  Abuzar   20          70
# statical data:              Age  Percentage
# count   5.000000    5.000000
# mean   20.400000   80.200000
# std     0.894427   12.755391
# min    20.000000   69.000000
# 25%    20.000000   70.000000
# 50%    20.000000   75.000000
# 75%    20.000000   89.000000
# max    22.000000   98.000000

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Gohar',20,75)
df.loc[4]=('Abuzar',20,70)
df['remark']=None
print(df)
# Out:
#      Name  Age  Percentage remark
# 0  Shadab   20          69   None
# 1    Aman   22          98   None
# 2    Awez   20          89   None
# 3   Gohar   20          75   None
# 4  Abuzar   20          70   None

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
print(df)
print("no of observation:",df["Name"].size)
m=df.isnull()
print("missing value:",m)
d=df.duplicated()
print(d)
# Out:
#      Name  Age  Percentage
# 0  Shadab   20          69
# 1    Aman   22          98
# 2    Awez   20          89
# 3    Ghar   20          75
# 4  Abuzar   20          70
# no of observation: 5
# missing value:     Name    Age  Percentage
# 0  False  False       False
# 1  False  False       False
# 2  False  False       False
# 3  False  False       False
# 4  False  False       False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
df['remark']=None
print(df)
df.drop(labels=['remark'],axis=1,inplace=True)
print(df)
df.dropna(axis=0,inplace=True)
print(df)
# Out:
#      Name  Age  Percentage remark
# 0  Shadab   20          69   None
# 1    Aman   22          98   None
# 2    Awez   20          89   None
# 3    Ghar   20          75   None
# 4  Abuzar   20          70   None
#      Name  Age  Percentage
# 0  Shadab   20          69
# 1    Aman   22          98
# 2    Awez   20          89
# 3    Ghar   20          75
# 4  Abuzar   20          70
#      Name  Age  Percentage
# 0  Shadab   20          69
# 1    Aman   22          98
# 2    Awez   20          89
# 3    Ghar   20          75
# 4  Abuzar   20          70

# %%
import pandas as pd
import matplotlib.pyplot as plt
#Creating Da Frame
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
df.loc[5]=('Mudasir',24,78)
df.loc[6]=('Raza',23,79)
df.loc[7]=('Sibtain',25,55)
df.loc[8]=('Sadiq',21,85)
df.loc[9]=('Ayman',26,86)
#view Dataframe
print(df)
#ploting line plot
df.plot(x="Name",y="Percentage")
plt.title('Line Plot Name vs Percentages')
plt.xlabel('Name of student')
plt.ylabel('percentage')
plt.show()
# Out:
#       Name  Age  Percentage
# 0   Shadab   20          69
# 1     Aman   22          98
# 2     Awez   20          89
# 3     Ghar   20          75
# 4   Abuzar   20          70
# 5  Mudasir   24          78
# 6     Raza   23          79
# 7  Sibtain   25          55
# 8    Sadiq   21          85
# 9    Ayman   26          86

# %%
import pandas as pd
import matplotlib.pyplot as plt
#Creating Da Frame
df=pd.DataFrame(columns=['Name','Age','Percentage']);
df.loc[0]=('Shadab',20,69)
df.loc[1]=('Aman',22,98)
df.loc[2]=('Awez',20,89)
df.loc[3]=('Ghar',20,75)
df.loc[4]=('Abuzar',20,70)
df.loc[5]=('Mudasir',24,78)
df.loc[6]=('Raza',23,79)
df.loc[7]=('Sibtain',25,55)
df.loc[8]=('Sadiq',21,85)
df.loc[9]=('Ayman',26,86)
#view Dataframe
print(df)
#ploting line plot
plt.scatter(x=df['Name'],y=df['Percentage'])
plt.title('Line Plot Name vs Percentages')
plt.xlabel('Name of student')
plt.ylabel('percentage')
plt.show()
# Out:
#       Name  Age  Percentage
# 0   Shadab   20          69
# 1     Aman   22          98
# 2     Awez   20          89
# 3     Ghar   20          75
# 4   Abuzar   20          70
# 5  Mudasir   24          78
# 6     Raza   23          79
# 7  Sibtain   25          55
# 8    Sadiq   21          85
# 9    Ayman   26          86
